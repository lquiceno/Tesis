# %%
import pandas as pd
# Out:
# /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# Leer el archivo txt y cargarlo en un DataFrame
df_background = pd.read_csv('df_b_lucas.txt', sep='\t')
df_background
# Out:
#                stat  ifar       time_H1      tid_H1  coa_phase_H1    snr_H1  \
# 0         11.294158   NaN  1.241069e+09  1127235331      0.834842  5.409212
# 1          9.403015   NaN  1.241069e+09   771126882     -2.499064  5.989699
# 2         15.353808   NaN  1.241069e+09   453317800      2.262940  6.200522
# 3         10.206897   NaN  1.241069e+09  2171455454      0.955250  5.503916
# 4          9.654624   NaN  1.241069e+09   580025962     -0.938532  5.275168
# ...             ...   ...           ...         ...           ...       ...
# 86376744  10.505274   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 86376745   5.755412   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 86376746  10.592489   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 86376747   5.784550   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 86376748   6.391989   NaN -1.000000e+00          -1     -1.000000 -1.000000
#
# ...

# %%
# Leer el archivo txt y cargarlo en un DataFrame
df_background_exc = pd.read_csv('df_b_exc_lucas.txt', sep='\t')
df_background_exc
# Out:
#                stat  ifar       time_H1      tid_H1  coa_phase_H1    snr_H1  \
# 0         11.294158   NaN  1.241069e+09  1127235331      0.834842  5.409212
# 1          9.403015   NaN  1.241069e+09   771126882     -2.499064  5.989699
# 2         15.353808   NaN  1.241069e+09   453317800      2.262940  6.200522
# 3         10.206897   NaN  1.241069e+09  2171455454      0.955250  5.503916
# 4          9.654624   NaN  1.241069e+09   580025962     -0.938532  5.275168
# ...             ...   ...           ...         ...           ...       ...
# 80182825   5.090391   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 80182826  10.505274   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 80182827  10.592489   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 80182828   5.784550   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 80182829   6.391989   NaN -1.000000e+00          -1     -1.000000 -1.000000
#
# ...

# %%
background_SNR = df_background.sample(n=1916583 , replace=False, random_state=42)


background_SNR
# Out:
#                stat  ifar       time_H1      tid_H1  coa_phase_H1    snr_H1  \
# 17816696   4.183380   NaN  1.241128e+09   302933848      2.761589  5.232667
# 49490116   7.727292   NaN  1.241423e+09    37374621     -2.771329  5.738260
# 55335080  11.296075   NaN  1.241582e+09   663440558     -1.804354  6.424503
# 38773711  15.634021   NaN  1.241560e+09  1954222950      3.132144  5.128339
# 48624616   7.796479   NaN  1.241662e+09   331406446      1.282000  5.371046
# ...             ...   ...           ...         ...           ...       ...
# 13608034  11.014588   NaN  1.241268e+09   993387280     -1.674996  5.696897
# 30854704  10.270576   NaN  1.241639e+09  1890461227     -2.662703  5.279950
# 3264614   15.361928   NaN  1.241132e+09    31148581     -1.880110  5.734617
# 29775250   8.121799   NaN  1.241135e+09   715224250      1.796237  5.669559
# 18949356   9.051553   NaN  1.241331e+09    42539461     -2.233351  5.343326
#
# ...

# %%
# Guardar el dataframe en un archivo CSV
background_SNR.to_csv('background_SNR.txt', sep='\t', index=False)

# %%
background_exc_SNR = df_background_exc.sample(n=1916583 , replace=False, random_state=42)


background_exc_SNR
# Out:
#                stat  ifar       time_H1      tid_H1  coa_phase_H1    snr_H1  \
# 73901298   3.152152   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 76261546   1.275224   NaN -1.000000e+00          -1     -1.000000 -1.000000
# 58526106   6.655539   NaN  1.241555e+09  1382516860     -0.755439  5.352562
# 49262673  10.402985   NaN  1.241429e+09  1032576748     -0.292338  5.383071
# 22069586  12.045845   NaN  1.241525e+09  1925128449      0.399967  5.196505
# ...             ...   ...           ...         ...           ...       ...
# 13792597   1.541340   NaN  1.241260e+09   906588314      1.424748  5.024083
# 31316160  11.192050   NaN  1.241423e+09   516452550     -0.688853  6.074977
# 51152766  11.092234   NaN  1.241327e+09   380699742      1.049317  5.734380
# 31568450   5.730298   NaN  1.241155e+09   428027904      1.995036  5.680272
# 19634210   7.782737   NaN  1.241504e+09   487317766     -0.134320  5.727056
#
# ...

# %%
# Guardar el dataframe en un archivo CSV
background_exc_SNR.to_csv('background_exc_SNR.txt',  sep='\t', index=False)
